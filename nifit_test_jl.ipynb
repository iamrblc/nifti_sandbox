# %% [markdown]
# # Handling nifti files in Julia

# %% [markdown]
# ## Necessary packages

# %%
using NIfTI
using ImageView
using Plots

# %% [markdown]
# ## Reading nifti files

# %%
nifti_path = "test_nifti_1.nii"
img = niread(nifti_path);

# %%
vsize = voxel_size(img.header)
tr = time_step(img.header)
# Out:
# 0.0

# %%
println(vsize)
println(tr)
# Out:
# [2.0, 2.0, 2.0]
# 0.0

# %%
vsize
# Out:
# 3-element Vector{Float64}:
#  2.0
#  2.0
#  2.0

# %%
img.header
# Out:
# NIfTI.NIfTI1Header(348, (0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00), (0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00), 0, 0, 114, 0, (3, 41, 51, 41, 1, 1, 1, 1), 0.0f0, 0.0f0, 0.0f0, 0, 16, 32, 0, (-1.0f0, 2.0f0, 2.0f0, 2.0f0, 0.0f0, 0.0f0, 0.0f0, 0.0f0), 352.0f0, 1.0f0, 0.0f0, 0, 0, 10, 0.0f0, 0.0f0, 0.0f0, 0.0f0, 0, 0, (0x73, 0x70, 0x6d, 0x5f, 0x73, 0x70, 0x6d, 0x3a, 0x62, 0x65, 0x74, 0x61, 0x20, 0x28, 0x30, 0x30, 0x30, 0x31, 0x29, 0x20, 0x2d, 0x20, 0x53, 0x6e, 0x28, 0x31, 0x29, 0x20, 0x53, 0x2a, 0x62, 0x66, 0x28, 0x31, 0x29, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00), (0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00), 2, 2, 0.0f0, 1.0f0, 0.0f0, 40.0f0, -50.0f0, -40.0f0, (-2.0f0, 0.0f0, 0.0f0, 40.0f0), (0.0f0, 2.0f0, 0.0f0, -50.0f0), (0.0f0, 0.0f0, 2.0f0, -40.0f0), (0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00), (0x6e, 0x2b, 0x31, 0x00))

# %% [markdown]
# ## Displaying the image

# %%
# This is ImageView line that opens it in a new window
#imshow(img[:,:,15])
# This is a plot simillar to what Matplotlib does in Python
heatmap(img[:,:,16], color =:inferno, axis = true)
